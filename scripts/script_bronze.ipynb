# %%
import pandas as pd

# %% [markdown]
# # Leitura do dataset

# %%
df_car_teste = pd.read_csv('/Volumes/worskpace_car_insurance/default/bronze/car_insurance_premium_dataset.csv')
df_car = pd.read_csv('/Volumes/worskpace_car_insurance/default/bronze/car_insurance_premium_dataset_TEST.csv')

# %% [markdown]
# ## Lendo as primeiras linnhas dos CSVs

# %%
def heads_tabelas(df, df_teste, n=5):
    #acredito que o primeiro dataframe seja de treino para o modelo, já que o segunndo é o de teste
    print("Dataframe de Treino: ")
    display(df.head(n))
    print("Dataframe de Teste: ")
    display(df_teste.head(n))

# %%
heads_tabelas(df_car, df_car_teste)
# Out:
# Dataframe de Treino:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Driver Age</th><th>Driver Experience</th><th>Previous Accidents</th><th>Annual Mileage (x1000 km)</th><th>Car Manufacturing Year</th><th>Car Age</th><th>Insurance Premium ($)</th></tr></thead><tbody><tr><td>56</td><td>7</td><td>0</td><td>22</td><td>2009</td><td>16</td><td>489.4</td></tr><tr><td>46</td><td>23</td><td>2</td><td>21</td><td>1990</td><td>35</td><td>491.45</td></tr><tr><td>32</td><td>10</td><td>5</td><td>13</td><td>1997</td><td>28</td><td>501.55</td></tr><tr><td>60</td><td>16</td><td>1</td><td>16</td><td>2005</td><td>20</td><td>487.5</td></tr><tr><td>25</td><td>7</td><td>4</td><td>17</td><td>2003</td><td>22</td><td>501.95</td></tr></tbody></table></div>
# Dataframe de Teste:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Driver Age</th><th>Driver Experience</th><th>Previous Accidents</th><th>Annual Mileage (x1000 km)</th><th>Car Manufacturing Year</th><th>Car Age</th><th>Insurance Premium ($)</th></tr></thead><tbody><tr><td>56</td><td>32</td><td>4</td><td>17</td><td>2002</td><td>23</td><td>488.35</td></tr><tr><td>46</td><td>19</td><td>0</td><td>21</td><td>2025</td><td>0</td><td>486.15</td></tr><tr><td>32</td><td>11</td><td>4</td><td>15</td><td>2020</td><td>5</td><td>497.55</td></tr><tr><td>60</td><td>0</td><td>4</td><td>19</td><td>1991</td><td>34</td><td>498.35</td></tr><tr><td>25</td><td>7</td><td>0</td><td>13</td><td>2005</td><td>20</td><td>495.55</td></tr></tbody></table></div>

# %% [markdown]
# ## Verificar o schema

# %%
print("Dataframe de Treino: ")
display(df_car.dtypes)
print("Dataframe de Teste: ")
display(df_car_teste.dtypes)
# Out:
# Dataframe de Treino:
# Driver Age                     int64
# Driver Experience              int64
# Previous Accidents             int64
# Annual Mileage (x1000 km)      int64
# Car Manufacturing Year         int64
# Car Age                        int64
# Insurance Premium ($)        float64
# dtype: object
# Dataframe de Teste:
# Driver Age                     int64
# Driver Experience              int64
# Previous Accidents             int64
# Annual Mileage (x1000 km)      int64
# Car Manufacturing Year         int64
# Car Age                        int64
# Insurance Premium ($)        float64
# dtype: object

# %% [markdown]
# ## Verificar informaçoes gerais

# %%
print("Dataframe de Treino: ")
display(df_car.shape)
print("Dataframe de Teste: ")
display(df_car_teste.shape)

# %%
print("Dataframe de Treino: ")
display(df_car.info())
print("Dataframe de Teste: ")
display(df_car_teste.info())

# %%
print("Dataframe de Treino: ")
df_car.describe()

# %%
print("Dataframe de Teste: ")
df_car_teste.describe()
